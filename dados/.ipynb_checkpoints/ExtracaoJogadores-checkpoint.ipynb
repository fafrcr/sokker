# %% [markdown]
# ## *Rodar notebook toda quinta-feira já que às quintas os atletas têm suas habilidades atualizadas após os treinos e os jogos da semana*

# %%
import pandas as pd
from functions import clube_id_e_sessao, pega_dados, conecta_ao_db
from datetime import datetime

# %%
# Mantendo o padrão de como o sokker mostra as datas nos dados que disponibiliza
agora= str(datetime.now()).split('.')[0]

print("Data:", agora)
# Out:
# Data: 2022-01-20 17:25:46

# %%
sessao, club_id= clube_id_e_sessao()
# Out:
# Login: fabin99
# Password: ········
# Clube ID: 79085

# %% [markdown]
# Como meu clube não pode ter valores nulos, os dos outros usuários sim (não tenho acesso a alguns dados de seus jogadores), eu insiro uma cláusula if antes de iniciar a inserção dos dados na base de dados para conferir.

# %%
# URL da API
url= f'https://sokker.org/xml/players-{club_id}.xml'

# Pegando os dados dos atletas
df_players= pega_dados(url, sessao, search= 'player')

# Inserindo a data de hoje que será importante para acompanharmos suas evoluções
df_players= df_players.assign(date_extracted= agora)

# Soma de valores nulos ou duplicados
nulos= df_players.isnull().sum().sum()
duplicados=  df_players.duplicated().sum()


if (nulos > 0) or (duplicados > 0):
    print('Há valores nulos ou duplicados. Confira os dados e tente novamente.')
    
else:
    print('Não há valores nulos ou duplicados. Inserindo dados na base de dados "dados.sokker.db"...')
    
    db= conecta_ao_db('dados_sokker.db')
    curs= db.cursor()
    
    df_players.to_sql('players', con=db, if_exists='append', index= False) 
    print('Dados extraídos com sucesso!')
# Out:
# Não há valores nulos ou duplicados. Inserindo dados na base de dados "dados.sokker.db"...
# Dados extraídos com sucesso!

# %%
df = pd.read_sql_query("SELECT * FROM players", db)

# %%
df
# Out:
#            ID       date_extracted           name      surname  countryID  \
# 0    36519432  2021-07-27 14:44:35        Krastan    Apostolov         54
# 1    37968035  2021-07-27 14:44:35        Romildo   Barbadiano         21
# 2    37968034  2021-07-27 14:44:35        Giovani  Barriguinha         21
# 3    36103236  2021-07-27 14:44:35         Ilario   Bartolozzi         10
# 4    37968028  2021-07-27 14:44:35        Cecilio   Bazzarella         21
# ..        ...                  ...            ...          ...        ...
# 605  37702007  2022-01-20 17:25:46        Martino        Testa         10
# 606  37766478  2022-01-20 17:25:46            Dan     Thystrup         29
# 607  37533726  2022-01-20 17:25:46          Tazar    Trbojević         39
# 608  37463857  2022-01-20 17:25:46  Gligor-Bogdan     Vînătoru          9
# 609  37698846  2022-01-20 17:25:46           Erim     Yiğitata         41
#
#      age  teamID     wage  height  weight  ...  skillStamina  skillTeamwork  \
# 0     29   79085  33900.0   177.0    71.5  ...             9              1
# 1     29   79085   3900.0   171.0    63.9  ...             0              1
# 2     27   79085   2600.0   172.0    76.3  ...             3              1
# 3     29   79085  16900.0   169.0    67.3  ...            11              1
# 4     20   79085   4800.0   175.0    77.4  ...             1              2
# ..   ...     ...      ...     ...     ...  ...           ...            ...
# 605   23   79085  10200.0   180.0    80.2  ...             6              3
# 606   22   79085  11800.0   175.0    72.8  ...             2              8
# 607   22   79085   7900.0   164.0    67.4  ...             9              7
# 608   25   79085   9900.0   165.0    59.6  ...             5              6
# 609   23   79085  12800.0   179.0    76.1  ...             8              6
#
#      skillDiscipline  skillPace  skillTechnique  skillPassing  skillKeeper  \
# 0                  5         15               3             9           10
# 1                  1          5               8             3            0
# 2                  0          6               2             5            1
# 3                  9         13               7             8            0
# 4                  1          7               1             9            0
# ..               ...        ...             ...           ...          ...
# 605                5         11               9             2            1
# 606                8         12               6             9            0
# 607                6         11               4             6            0
# 608                6         12               9             7            0
# 609                5          8               9            11            2
#
#      skillDefending  skillPlaymaking  skillScoring
# 0                 5                5             3
# 1                 8                1             3
# 2                 5                1             4
# 3                 8                9             8
# 4                 5                7             7
# ..              ...              ...           ...
# 605               2                4            12
# 606               9               10             4
# 607               8                2             8
# 608               4                9             8
# 609              10                9             9
#
# [610 rows x 36 columns]

# %%
len(df)
# Out:
# 610

# %%
# Salvando alterações
db.commit()

# Fechando conexão com a base de dados
db.close()
