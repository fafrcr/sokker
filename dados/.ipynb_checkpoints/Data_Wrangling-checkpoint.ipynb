# %%
import pandas as pd
from functions import conecta_ao_db

# %%
db= conecta_ao_db('dados_sokker.db')
curs= db.cursor()

df_pl = pd.read_sql_query("SELECT * FROM players", db)
pl_stats= pd.read_csv('playersStats.csv')

# %%
pl_stats.head()
# Out:
#     matchID Numero                    Nome Posicao Nota  Tempo  Chutes  \
# 0  38144835      1       "Josimar Bendler"    "GK"   33     90       0
# 1  38144835      2   "Giovani Barriguinha"   "DEF"   19     90       0
# 2  38144835      3          "Amado Grotto"   "DEF"   19     90       0
# 3  38144835      4    "Romildo Barbadiano"   "DEF"   26     90       0
# 4  38144835      5         "Renê Santinho"   "DEF"   27     90       0
#
#    Faltas  Ofens  Defens  yellowCards  redCards  Goals  Assis  \
# 0       0      1       0            0         0      0      0
# 1       0      6       7            0         0      0      0
# 2       0      7       1            0         0      0      0
# 3       0      4       9            0         0      0      0
# 4       0      8       9            0         0      0      0
#
#                    Data
# 0   "2021-07-18 21:58"
# 1    "2021-07-18 21:58"
# 2    "2021-07-18 21:58"
# 3    "2021-07-18 21:58"
# 4    "2021-07-18 21:58"

# %%
pl_stats.isnull().sum()
# Out:
# matchID        0
# Numero         0
# Nome           0
# Posicao        0
# Nota           0
# Tempo          0
# Chutes         0
# Faltas         0
# Ofens          0
# Defens         0
# yellowCards    0
# redCards       0
# Goals          0
# Assis          0
# Data           0
# dtype: int64
